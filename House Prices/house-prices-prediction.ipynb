# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/house-prices-advanced-regression-techniques/sample_submission.csv
# /kaggle/input/house-prices-advanced-regression-techniques/data_description.txt
# /kaggle/input/house-prices-advanced-regression-techniques/train.csv
# /kaggle/input/house-prices-advanced-regression-techniques/test.csv

# %%
# Importing more libraries
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn import metrics
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import Ridge
from sklearn.ensemble import RandomForestRegressor
from keras.optimizers import Adam

# %% [markdown]
# Loading and preparing the data

# %%
# Reading the dataset
train_df = pd.read_csv('/kaggle/input/house-prices-advanced-regression-techniques/train.csv')
test_df = pd.read_csv('/kaggle/input/house-prices-advanced-regression-techniques/test.csv')
submission = pd.read_csv('/kaggle/input/house-prices-advanced-regression-techniques/sample_submission.csv')
train_df.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %%
test_df.head(10)
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
# 5  1466          60       RL         75.0    10000   Pave   NaN      IR1
# 6  1467          20       RL          NaN     7980   Pave   NaN      IR1
# 7  1468          60       RL         63.0     8402   Pave   NaN      IR1
# 8  1469          20       RL         85.0    10176   Pave   NaN      Reg
# 9  1470          20       RL         70.0     8400   Pave   NaN      Reg
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# ...

# %%
train_df.shape, test_df.shape
# Out:
# ((1460, 81), (1459, 80))

# %%
train_df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1455 non-null   object
#  3   LotFrontage    1232 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   Alley          107 non-null    object
#  7   LotShape       1459 non-null   object
#  8   LandContour    1459 non-null   object
#  9   Utilities      1457 non-null   object
#  10  LotConfig      1459 non-null   object
#  11  LandSlope      1459 non-null   object
#  12  Neighborhood   1459 non-null   object
#  13  Condition1     1459 non-null   object
#  14  Condition2     1459 non-null   object
#  15  BldgType       1459 non-null   object
#  16  HouseStyle     1459 non-null   object
# ...

# %%
train_df['Train'] = 1
test_df['Train'] = 0

# %%
# Merging the data
combined_df = pd.concat([train_df, test_df], axis=0)
combined_df.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolQC  Fence MiscFeature MiscVal MoSold YrSold  \
# 0         Lvl    AllPub  ...    NaN    NaN         NaN       0      2   2008
# ...

# %%
# Droping NaN values
combined = combined_df.dropna(axis=1)
combined.head(10)
# Out:
#    Id  MSSubClass  LotArea Street LotShape LandContour LotConfig LandSlope  \
# 0   1          60     8450   Pave      Reg         Lvl    Inside       Gtl
# 1   2          20     9600   Pave      Reg         Lvl       FR2       Gtl
# 2   3          60    11250   Pave      IR1         Lvl    Inside       Gtl
# 3   4          70     9550   Pave      IR1         Lvl    Corner       Gtl
# 4   5          60    14260   Pave      IR1         Lvl       FR2       Gtl
# 5   6          50    14115   Pave      IR1         Lvl    Inside       Gtl
# 6   7          20    10084   Pave      Reg         Lvl    Inside       Gtl
# 7   8          60    10382   Pave      IR1         Lvl    Corner       Gtl
# 8   9          50     6120   Pave      Reg         Lvl    Inside       Gtl
# 9  10         190     7420   Pave      Reg         Lvl    Corner       Gtl
#
#   Neighborhood Condition1  ... OpenPorchSF EnclosedPorch 3SsnPorch  \
# 0      CollgCr       Norm  ...          61             0         0
# ...

# %%
combined.shape
# Out:
# (2919, 47)

# %%
# Dropping id column, because it doesn't contain valuable information
combinednew = combined.drop('Id', axis=1)
combinednew.shape
# Out:
# (2919, 46)

# %%
combineddum = pd.get_dummies(combinednew)
combineddum.shape
# Out:
# (2919, 150)

# %%
# separating data back into train and test parts
mytrain = combineddum[combineddum['Train'] == 1]
mytest = combineddum[combineddum['Train'] == 0]
mytrain = mytrain.drop('Train', axis=1)
mytest = mytest.drop('Train', axis=1)
mytrain.shape, mytest.shape
# Out:
# ((1460, 149), (1459, 149))

# %%
x = mytrain
y = train_df['SalePrice']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25)
x_test2 = mytest
x_train.shape, y_train.shape, x_test.shape, y_test.shape, x_test2.shape
# Out:
# ((1095, 149), (1095,), (365, 149), (365,), (1459, 149))

# %% [markdown]
# Trying linaear regression first

# %%
linregr = Ridge(alpha=0.01)
linregr.fit(x_train, y_train)
# Out:
# Ridge(alpha=0.01)

# %%
mean_squared_error(y_test, linregr.predict(x_test), squared=False)
# Out:
# 29500.458294481752

# %%
r2_score(y_test, linregr.predict(x_test))
# Out:
# 0.8526143444271833

# %%
linregr.predict(x_test2)
# Out:
# array([115035.53700036, 149225.33069192, 168717.58924933, ...,
#        142308.95065812, 129360.28591374, 222182.42264412])

# %% [markdown]
# Trying Gradient Boosting Regressor

# %%
gradregr = GradientBoostingRegressor(random_state=0)
gradregr.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor(random_state=0)

# %%
mean_squared_error(y_test, gradregr.predict(x_test), squared=False)
# Out:
# 30652.9778044939

# %%
r2_score(y_test, gradregr.predict(x_test))
# Out:
# 0.8408733084733433

# %% [markdown]
# Trying random forest regressor

# %%
regrforest = RandomForestRegressor()
regrforest.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
mean_squared_error(y_test, regrforest.predict(x_test), squared=False)
# Out:
# 31187.801239458488

# %%
r2_score(y_test, regrforest.predict(x_test))
# Out:
# 0.8352720827738535

# %% [markdown]
# Trying neural network

# %%
model = tf.keras.Sequential()
model.add(keras.layers.Dense(12, activation="relu", input_dim=149))
# model.add(keras.layers.Dense(64, activation="relu"))
# model.add(keras.layers.Dense(16, activation="relu"))
model.add(keras.layers.Dense(8, activation="relu"))
model.add(keras.layers.Dense(1, activation="linear"))

# %%
model.compile(loss='mean_squared_error', optimizer=Adam(learning_rate=1e-3, decay=1e-3 / 200))

# %%
history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=2500, batch_size=1095, verbose=0)

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.title('Training History'),
plt.xlabel('Epoch'),
plt.ylabel('Validation Loss')
plt.show()

# %%
mean_squared_error(y_test, model.predict(x_test), squared=False)
# Out:
# 12/12 [==============================] - 0s 1ms/step
# 49583.05601574649

# %%
yhat = gradregr.predict(x_test2)
x_test2["SalePrice"] = yhat

# %%
submission["SalePrice"] = yhat
submission.head()
# Out:
#      Id      SalePrice
# 0  1461  131311.957471
# 1  1462  156686.525029
# 2  1463  174003.770868
# 3  1464  184593.802512
# 4  1465  218647.637554

# %%
submission.to_csv("submission.csv", index = False)
